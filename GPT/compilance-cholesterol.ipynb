# %%
# =========================================================
# Cell 1: Import libraries and load cholesterol dataset
# =========================================================
import pandas as pd
import numpy as np

# Load file
file_path = "meal_to_yoga_top1_contrastive_Cholesterol.xlsx"
df = pd.read_excel(file_path)

# Keep relevant columns only
cols = [
    "meal_plan", "meal_day", "meal_time", "meal_name", "meal_description",
    "Calories (kcal)", "Zinc (mg)", "Copper (mg)", "Iron (mg)",
    "Chromium (µg)", "Potassium (mg)", "Phosphorus (mg)",
    "Vitamin_B1 (Thiamin, mg)", "Vitamin_B2 (Riboflavin, mg)",
    "Vitamin_B3 (Niacin, mg)", "Vitamin_B6 (mg)",
    "Vitamin_B9 (Folate, µg)", "Vitamin_B12 (µg)",
    "Selenium (µg)", "Magnesium (mg)"
]
df = df[cols]

print("✅ Dataset loaded successfully — shape:", df.shape)
df.head(3)
# Out:
# ✅ Dataset loaded successfully — shape: (42, 20)
#   meal_plan meal_day  meal_time                       meal_name  \
# 0    Plan A   Monday    Morning       Spinach-mushroom omelette
# 1    Plan A   Monday  Afternoon   Tofu stir-fry with brown rice
# 2    Plan A   Monday    Evening  Baked cod with sautéed spinach
#
#                                     meal_description  Calories (kcal)  \
# 0           Egg omelette with spinach and mushrooms.              664
# 1  Tofu and veggies stir-fried, served with brown...              784
# 2             Baked cod with garlic sautéed spinach.              660
#
#    Zinc (mg)  Copper (mg)  Iron (mg)  Chromium (µg)  Potassium (mg)  \
# 0      2.540        0.363      5.079          9.180        1116.270
# 1      3.003        0.426      5.650         10.983        1409.389
# 2      2.519        0.363      4.759          9.821        1166.577
#
#    Phosphorus (mg)  Vitamin_B1 (Thiamin, mg)  Vitamin_B2 (Riboflavin, mg)  \
# 0          241.131                     0.388                        0.365
# 1          312.913                     0.432                        0.418
# 2          254.892                     0.357                        0.351
#
#    Vitamin_B3 (Niacin, mg)  Vitamin_B6 (mg)  Vitamin_B9 (Folate, µg)  \
# 0                    4.794            0.575                  124.452
# 1                    5.865            0.663                  144.389
# 2                    5.196            0.542                  126.497
#
#    Vitamin_B12 (µg)  Selenium (µg)  Magnesium (mg)
# 0             0.764         19.779         126.709
# 1             0.907         23.126         150.930
# 2             0.735         19.778         121.749

# %%
# =========================================================
# Cell 2: Standardize column names and meal_day order
# =========================================================
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "")
    .str.replace(")", "")
    .str.replace("+", "plus")
    .str.replace("µ", "u")
    .str.replace("-", "_")
    .str.replace(",", "")
)

weekday_order = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
df["meal_day"] = df["meal_day"].astype(str).str.strip().str.lower()
df["meal_day"] = pd.Categorical(df["meal_day"], categories=weekday_order, ordered=True)

print("✅ Column names cleaned and weekdays standardized:")
print(df.columns.tolist())
df.head(3)
# Out:
# ✅ Column names cleaned and weekdays standardized:
# ['meal_plan', 'meal_day', 'meal_time', 'meal_name', 'meal_description', 'calories_kcal', 'zinc_mg', 'copper_mg', 'iron_mg', 'chromium_ug', 'potassium_mg', 'phosphorus_mg', 'vitamin_b1_thiamin_mg', 'vitamin_b2_riboflavin_mg', 'vitamin_b3_niacin_mg', 'vitamin_b6_mg', 'vitamin_b9_folate_ug', 'vitamin_b12_ug', 'selenium_ug', 'magnesium_mg']
#   meal_plan meal_day  meal_time                       meal_name  \
# 0    Plan A   monday    Morning       Spinach-mushroom omelette
# 1    Plan A   monday  Afternoon   Tofu stir-fry with brown rice
# 2    Plan A   monday    Evening  Baked cod with sautéed spinach
#
#                                     meal_description  calories_kcal  zinc_mg  \
# 0           Egg omelette with spinach and mushrooms.            664    2.540
# 1  Tofu and veggies stir-fried, served with brown...            784    3.003
# 2             Baked cod with garlic sautéed spinach.            660    2.519
#
#    copper_mg  iron_mg  chromium_ug  potassium_mg  phosphorus_mg  \
# 0      0.363    5.079        9.180      1116.270        241.131
# 1      0.426    5.650       10.983      1409.389        312.913
# 2      0.363    4.759        9.821      1166.577        254.892
#
#    vitamin_b1_thiamin_mg  vitamin_b2_riboflavin_mg  vitamin_b3_niacin_mg  \
# 0                  0.388                     0.365                 4.794
# 1                  0.432                     0.418                 5.865
# 2                  0.357                     0.351                 5.196
#
#    vitamin_b6_mg  vitamin_b9_folate_ug  vitamin_b12_ug  selenium_ug  \
# 0          0.575               124.452           0.764       19.779
# 1          0.663               144.389           0.907       23.126
# 2          0.542               126.497           0.735       19.778
#
#    magnesium_mg
# 0       126.709
# 1       150.930
# 2       121.749

# %%
# =========================================================
# Cell 3: Define nutrient reference ranges (from WHO / NIH / DRI)
# =========================================================
nutrient_ranges = {
    "calories_kcal": (1800, 2200),
    "zinc_mg": (8, 11),
    "copper_mg": (0.9, 1.3),
    "iron_mg": (8, 18),
    "chromium_ug": (25, 35),
    "potassium_mg": (3400, 4700),
    "phosphorus_mg": (700, 1250),
    "vitamin_b1_thiamin_mg": (1.1, 1.2),
    "vitamin_b2_riboflavin_mg": (1.1, 1.3),
    "vitamin_b3_niacin_mg": (14, 35),
    "vitamin_b6_mg": (1.3, 2.0),
    "vitamin_b9_folate_ug": (300, 400),
    "vitamin_b12_ug": (2.4, 4.0),
    "selenium_ug": (55, 70),
    "magnesium_mg": (310, 420)
}

ranges_df = pd.DataFrame([
    {"Nutrient": k, "Min_Recommended": v[0], "Max_Recommended": v[1]}
    for k, v in nutrient_ranges.items()
])

print("✅ Real-world nutrient ranges for cholesterol plan:")
display(ranges_df)
# Out:
# ✅ Real-world nutrient ranges for cholesterol plan:
#                     Nutrient  Min_Recommended  Max_Recommended
# 0              calories_kcal           1800.0           2200.0
# 1                    zinc_mg              8.0             11.0
# 2                  copper_mg              0.9              1.3
# 3                    iron_mg              8.0             18.0
# 4                chromium_ug             25.0             35.0
# 5               potassium_mg           3400.0           4700.0
# 6              phosphorus_mg            700.0           1250.0
# 7      vitamin_b1_thiamin_mg              1.1              1.2
# 8   vitamin_b2_riboflavin_mg              1.1              1.3
# 9       vitamin_b3_niacin_mg             14.0             35.0
# 10             vitamin_b6_mg              1.3              2.0
# 11      vitamin_b9_folate_ug            300.0            400.0
# 12            vitamin_b12_ug              2.4              4.0
# 13               selenium_ug             55.0             70.0
# 14              magnesium_mg            310.0            420.0

# %%
# =========================================================
# Cell 4: Map dataset columns to nutrient names manually (explicit match)
# =========================================================
col_map = {
    "calories_kcal": "calories_kcal",
    "zinc_mg": "zinc_mg",
    "copper_mg": "copper_mg",
    "iron_mg": "iron_mg",
    "chromium_ug": "chromium_ug",
    "potassium_mg": "potassium_mg",
    "phosphorus_mg": "phosphorus_mg",
    "vitamin_b1_thiamin_mg": "vitamin_b1_thiamin_mg",
    "vitamin_b2_riboflavin_mg": "vitamin_b2_riboflavin_mg",
    "vitamin_b3_niacin_mg": "vitamin_b3_niacin_mg",
    "vitamin_b6_mg": "vitamin_b6_mg",
    "vitamin_b9_folate_ug": "vitamin_b9_folate_ug",
    "vitamin_b12_ug": "vitamin_b12_ug",
    "selenium_ug": "selenium_ug",
    "magnesium_mg": "magnesium_mg"
}

# Convert to numeric
for col in col_map.values():
    df[col] = pd.to_numeric(df[col], errors="coerce")

print("✅ Nutrient column mapping validated:")
for k, v in col_map.items():
    print(f"{k:25} --> {v}")
# Out:
# ✅ Nutrient column mapping validated:
# calories_kcal             --> calories_kcal
# zinc_mg                   --> zinc_mg
# copper_mg                 --> copper_mg
# iron_mg                   --> iron_mg
# chromium_ug               --> chromium_ug
# potassium_mg              --> potassium_mg
# phosphorus_mg             --> phosphorus_mg
# vitamin_b1_thiamin_mg     --> vitamin_b1_thiamin_mg
# vitamin_b2_riboflavin_mg  --> vitamin_b2_riboflavin_mg
# vitamin_b3_niacin_mg      --> vitamin_b3_niacin_mg
# vitamin_b6_mg             --> vitamin_b6_mg
# vitamin_b9_folate_ug      --> vitamin_b9_folate_ug
# vitamin_b12_ug            --> vitamin_b12_ug
# selenium_ug               --> selenium_ug
# magnesium_mg              --> magnesium_mg

# %%
# =========================================================
# Cell 5: Aggregate nutrient totals per day and plan
# =========================================================
agg_cols = list(col_map.values())
daily = df.groupby(["meal_plan", "meal_day"], as_index=False)[agg_cols].sum()

print("✅ Aggregated daily nutrient totals:")
display(daily.head())
# Out:
# ✅ Aggregated daily nutrient totals:
# /var/folders/jg/8wn2439s6y312d5jyqw78pc80000gn/T/ipykernel_53695/2961356842.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   daily = df.groupby(["meal_plan", "meal_day"], as_index=False)[agg_cols].sum()
#   meal_plan   meal_day  calories_kcal  zinc_mg  copper_mg  iron_mg  \
# 0    Plan A     monday           2108    8.062      1.152   15.488
# 1    Plan A    tuesday           2109    8.120      1.072   11.149
# 2    Plan A  wednesday           2169   10.776      1.126   13.335
# 3    Plan A   thursday           2094    9.523      1.158   10.132
# 4    Plan A     friday           2107    8.963      1.155    8.092
#
#    chromium_ug  potassium_mg  phosphorus_mg  vitamin_b1_thiamin_mg  \
# 0       29.984      3692.236        808.936                  1.177
# 1       31.365      3850.251        723.704                  1.188
# 2       25.149      4671.269       1015.166                  1.179
# 3       33.957      4655.730        874.352                  1.186
# 4       30.435      3839.081       1193.913                  1.194
#
#    vitamin_b2_riboflavin_mg  vitamin_b3_niacin_mg  vitamin_b6_mg  \
# 0                     1.134                15.855          1.780
# 1                     1.252                32.441          1.591
# 2                     1.211                32.424          1.709
# 3                     1.162                14.531          1.333
# 4                     1.176                22.318          1.928
#
#    vitamin_b9_folate_ug  vitamin_b12_ug  selenium_ug  magnesium_mg
# 0               395.338           2.406       62.683       399.388
# 1               360.558           3.222       63.968       338.844
# 2               370.885           2.638       61.427       386.327
# 3               318.463           2.509       58.861       410.494
# 4               305.882           3.049       56.952       319.567

# %%
# =========================================================
# Cell 6: Display generated vs recommended nutrient values
# =========================================================
plan_example = daily[daily["meal_plan"].str.contains("a", case=False)].head(3)
compare_table = []

for nutrient, (low, high) in nutrient_ranges.items():
    col = col_map[nutrient]
    for _, r in plan_example.iterrows():
        val = round(float(r[col]), 2)
        compare_table.append({
            "Meal_Plan": r["meal_plan"],
            "Meal_Day": r["meal_day"],
            "Nutrient": nutrient,
            "Generated_Value": val,
            "Target_Range": f"{low} - {high}"
        })

compare_df = pd.DataFrame(compare_table)
display(compare_df)
# Out:
#    Meal_Plan   Meal_Day                  Nutrient  Generated_Value  \
# 0     Plan A     monday             calories_kcal          2108.00
# 1     Plan A    tuesday             calories_kcal          2109.00
# 2     Plan A  wednesday             calories_kcal          2169.00
# 3     Plan A     monday                   zinc_mg             8.06
# 4     Plan A    tuesday                   zinc_mg             8.12
# 5     Plan A  wednesday                   zinc_mg            10.78
# 6     Plan A     monday                 copper_mg             1.15
# 7     Plan A    tuesday                 copper_mg             1.07
# 8     Plan A  wednesday                 copper_mg             1.13
# 9     Plan A     monday                   iron_mg            15.49
# 10    Plan A    tuesday                   iron_mg            11.15
# 11    Plan A  wednesday                   iron_mg            13.34
# 12    Plan A     monday               chromium_ug            29.98
# 13    Plan A    tuesday               chromium_ug            31.36
# 14    Plan A  wednesday               chromium_ug            25.15
# 15    Plan A     monday              potassium_mg          3692.24
# 16    Plan A    tuesday              potassium_mg          3850.25
# 17    Plan A  wednesday              potassium_mg          4671.27
# 18    Plan A     monday             phosphorus_mg           808.94
# 19    Plan A    tuesday             phosphorus_mg           723.70
# 20    Plan A  wednesday             phosphorus_mg          1015.17
# 21    Plan A     monday     vitamin_b1_thiamin_mg             1.18
# 22    Plan A    tuesday     vitamin_b1_thiamin_mg             1.19
# 23    Plan A  wednesday     vitamin_b1_thiamin_mg             1.18
# 24    Plan A     monday  vitamin_b2_riboflavin_mg             1.13
# 25    Plan A    tuesday  vitamin_b2_riboflavin_mg             1.25
# 26    Plan A  wednesday  vitamin_b2_riboflavin_mg             1.21
# 27    Plan A     monday      vitamin_b3_niacin_mg            15.86
# 28    Plan A    tuesday      vitamin_b3_niacin_mg            32.44
# 29    Plan A  wednesday      vitamin_b3_niacin_mg            32.42
# 30    Plan A     monday             vitamin_b6_mg             1.78
# 31    Plan A    tuesday             vitamin_b6_mg             1.59
# 32    Plan A  wednesday             vitamin_b6_mg             1.71
# 33    Plan A     monday      vitamin_b9_folate_ug           395.34
# 34    Plan A    tuesday      vitamin_b9_folate_ug           360.56
# 35    Plan A  wednesday      vitamin_b9_folate_ug           370.88
# 36    Plan A     monday            vitamin_b12_ug             2.41
# 37    Plan A    tuesday            vitamin_b12_ug             3.22
# 38    Plan A  wednesday            vitamin_b12_ug             2.64
# 39    Plan A     monday               selenium_ug            62.68
# 40    Plan A    tuesday               selenium_ug            63.97
# 41    Plan A  wednesday               selenium_ug            61.43
# 42    Plan A     monday              magnesium_mg           399.39
# 43    Plan A    tuesday              magnesium_mg           338.84
# 44    Plan A  wednesday              magnesium_mg           386.33
#
#    Target_Range
# 0   1800 - 2200
# 1   1800 - 2200
# 2   1800 - 2200
# 3        8 - 11
# 4        8 - 11
# 5        8 - 11
# 6     0.9 - 1.3
# 7     0.9 - 1.3
# 8     0.9 - 1.3
# 9        8 - 18
# 10       8 - 18
# 11       8 - 18
# 12      25 - 35
# 13      25 - 35
# 14      25 - 35
# 15  3400 - 4700
# 16  3400 - 4700
# 17  3400 - 4700
# 18   700 - 1250
# 19   700 - 1250
# 20   700 - 1250
# 21    1.1 - 1.2
# 22    1.1 - 1.2
# 23    1.1 - 1.2
# 24    1.1 - 1.3
# 25    1.1 - 1.3
# 26    1.1 - 1.3
# 27      14 - 35
# 28      14 - 35
# 29      14 - 35
# 30    1.3 - 2.0
# 31    1.3 - 2.0
# 32    1.3 - 2.0
# 33    300 - 400
# 34    300 - 400
# 35    300 - 400
# 36    2.4 - 4.0
# 37    2.4 - 4.0
# 38    2.4 - 4.0
# 39      55 - 70
# 40      55 - 70
# 41      55 - 70
# 42    310 - 420
# 43    310 - 420
# 44    310 - 420

# %%
# =========================================================
# Cell 7: Compute strict and partial TRUE/FALSE for all nutrients
# =========================================================
def evaluate_compliance(value, low, high, tolerance=0.05):
    if pd.isna(value):
        return np.nan, np.nan
    strict = low <= value <= high
    partial = (low * (1 - tolerance)) <= value <= (high * (1 + tolerance))
    return strict, partial

records = []
for _, row in daily.iterrows():
    record = {"meal_plan": row["meal_plan"], "meal_day": row["meal_day"]}
    for nutrient, (low, high) in nutrient_ranges.items():
        col = col_map[nutrient]
        val = row[col]
        strict, partial = evaluate_compliance(val, low, high)
        record[f"{nutrient}_value"] = round(val, 2)
        record[f"{nutrient}_strict"] = strict
        record[f"{nutrient}_partial"] = partial
    records.append(record)

compliance_df = pd.DataFrame(records)
display(compliance_df.head())
# Out:
#   meal_plan   meal_day  calories_kcal_value  calories_kcal_strict  \
# 0    Plan A     monday                 2108                  True
# 1    Plan A    tuesday                 2109                  True
# 2    Plan A  wednesday                 2169                  True
# 3    Plan A   thursday                 2094                  True
# 4    Plan A     friday                 2107                  True
#
#    calories_kcal_partial  zinc_mg_value  zinc_mg_strict  zinc_mg_partial  \
# 0                   True           8.06            True             True
# 1                   True           8.12            True             True
# 2                   True          10.78            True             True
# 3                   True           9.52            True             True
# 4                   True           8.96            True             True
#
#    copper_mg_value  copper_mg_strict  ...  vitamin_b9_folate_ug_partial  \
# 0             1.15              True  ...                          True
# 1             1.07              True  ...                          True
# 2             1.13              True  ...                          True
# 3             1.16              True  ...                          True
# 4             1.16              True  ...                          True
#
#    vitamin_b12_ug_value  vitamin_b12_ug_strict  vitamin_b12_ug_partial  \
# 0                  2.41                   True                    True
# 1                  3.22                   True                    True
# 2                  2.64                   True                    True
# 3                  2.51                   True                    True
# 4                  3.05                   True                    True
#
#    selenium_ug_value  selenium_ug_strict  selenium_ug_partial  \
# 0              62.68                True                 True
# 1              63.97                True                 True
# 2              61.43                True                 True
# 3              58.86                True                 True
# 4              56.95                True                 True
#
#    magnesium_mg_value  magnesium_mg_strict  magnesium_mg_partial
# 0              399.39                 True                  True
# 1              338.84                 True                  True
# 2              386.33                 True                  True
# 3              410.49                 True                  True
# 4              319.57                 True                  True
#
# [5 rows x 47 columns]

# %%
# =========================================================
# Cell 8: Count nutrients within target range per day
# =========================================================
strict_cols = [c for c in compliance_df.columns if "_strict" in c]
partial_cols = [c for c in compliance_df.columns if "_partial" in c]

compliance_df["strict_count"] = compliance_df[strict_cols].sum(axis=1)
compliance_df["partial_count"] = compliance_df[partial_cols].sum(axis=1)
compliance_df["total_nutrients"] = len(strict_cols)

compliance_df["strict_compliance_%"] = round(
    compliance_df["strict_count"] / compliance_df["total_nutrients"] * 100, 2)
compliance_df["partial_compliance_%"] = round(
    compliance_df["partial_count"] / compliance_df["total_nutrients"] * 100, 2)

print("✅ Nutrient compliance count per plan/day:")
display(compliance_df[
    ["meal_plan", "meal_day", "strict_count", "partial_count",
     "total_nutrients", "strict_compliance_%", "partial_compliance_%"]
])
# Out:
# ✅ Nutrient compliance count per plan/day:
#    meal_plan   meal_day  strict_count  partial_count  total_nutrients  \
# 0     Plan A     monday            15             15               15
# 1     Plan A    tuesday            15             15               15
# 2     Plan A  wednesday            15             15               15
# 3     Plan A   thursday            15             15               15
# 4     Plan A     friday            15             15               15
# 5     Plan A   saturday            15             15               15
# 6     Plan A     sunday            15             15               15
# 7     Plan B     monday            15             15               15
# 8     Plan B    tuesday            15             15               15
# 9     Plan B  wednesday            15             15               15
# 10    Plan B   thursday            15             15               15
# 11    Plan B     friday            15             15               15
# 12    Plan B   saturday            15             15               15
# 13    Plan B     sunday            15             15               15
#
#     strict_compliance_%  partial_compliance_%
# 0                 100.0                 100.0
# 1                 100.0                 100.0
# 2                 100.0                 100.0
# 3                 100.0                 100.0
# 4                 100.0                 100.0
# 5                 100.0                 100.0
# 6                 100.0                 100.0
# 7                 100.0                 100.0
# 8                 100.0                 100.0
# 9                 100.0                 100.0
# 10                100.0                 100.0
# 11                100.0                 100.0
# 12                100.0                 100.0
# 13                100.0                 100.0

# %%
# =========================================================
# Cell 9: Compute average compliance across days per plan
# =========================================================
summary = (
    compliance_df.groupby("meal_plan")[["strict_compliance_%", "partial_compliance_%"]]
    .mean()
    .reset_index()
)

summary.rename(columns={
    "strict_compliance_%": "Avg_Strict_Compliance(%)",
    "partial_compliance_%": "Avg_Partial_Compliance(%)"
}, inplace=True)

print("✅ Average compliance summary per plan:")
display(summary)
# Out:
# ✅ Average compliance summary per plan:
#   meal_plan  Avg_Strict_Compliance(%)  Avg_Partial_Compliance(%)
# 0    Plan A                     100.0                      100.0
# 1    Plan B                     100.0                      100.0

# %%
# =========================================================
# Cell 10: Generate summary story for research writing
# =========================================================
stories = []
for _, row in summary.iterrows():
    plan = row["meal_plan"]
    s = row["Avg_Strict_Compliance(%)"]
    p = row["Avg_Partial_Compliance(%)"]

    story = (
        f"For {plan}, mean strict compliance was {s:.1f}% "
        f"and partial compliance {p:.1f}%. "
        f"This indicates that, on average, {s:.1f}% of the 14 evaluated nutrients "
        f"fell strictly within the reference range, "
        f"while {p:.1f}% were within ±5% of their target range."
    )
    stories.append(story)

print("🧾 Narrative Summary for Research Paper:\n")
for s in stories:
    print(s)
# Out:
# 🧾 Narrative Summary for Research Paper:
#
# For Plan A, mean strict compliance was 100.0% and partial compliance 100.0%. This indicates that, on average, 100.0% of the 14 evaluated nutrients fell strictly within the reference range, while 100.0% were within ±5% of their target range.
# For Plan B, mean strict compliance was 100.0% and partial compliance 100.0%. This indicates that, on average, 100.0% of the 14 evaluated nutrients fell strictly within the reference range, while 100.0% were within ±5% of their target range.
