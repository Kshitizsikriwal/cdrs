# %%
# =========================================================
# Cell 1: Setup environment and load dataset
# =========================================================
import pandas as pd
import numpy as np
from difflib import get_close_matches

# Load file
file_path = "meal_to_yoga_top1_contrastive_Asthma.xlsx"
df = pd.read_excel(file_path)

# Select relevant columns
cols = [
    "meal_plan", "meal_day", "meal_time", "meal_name", "meal_description",
    "Calories (kcal)", "Total_Fat (g)", "Protein (g)",
    "Dietary_Fiber (g)", "Added_Sugar (g)", "Vitamin_D (µg)",
    "Magnesium (mg)", "Selenium (µg)", "Omega-3 (ALA, g)", "EPA + DHA (mg)"
]
df = df[cols]

print("✅ Dataset loaded successfully — shape:", df.shape)
df.head()
# Out:
# ✅ Dataset loaded successfully — shape: (42, 15)
#   meal_plan meal_day  meal_time                      meal_name  \
# 0    Plan A   Monday    Morning              Oatmeal & Berries
# 1    Plan A   Monday  Afternoon     Chicken & Black Bean Salad
# 2    Plan A   Monday    Evening        Grilled Salmon & Quinoa
# 3    Plan A  Tuesday    Morning            Egg & Avocado Toast
# 4    Plan A  Tuesday  Afternoon  Turkey & Bell Pepper Stir-fry
#
#                                     meal_description  Calories (kcal)  \
# 0  Steel-cut oats with almonds, flaxseed, and mix...              450
# 1  Grilled chicken and black bean salad with spin...              700
# 2  Grilled salmon with lemon-dill, quinoa, and ro...              850
# 3  Scrambled eggs with spinach, served with avoca...              500
# 4  Lean turkey stir-fry with red and yellow bell ...              750
#
#    Total_Fat (g)  Protein (g)  Dietary_Fiber (g)  Added_Sugar (g)  \
# 0             15           15                 10                5
# 1             25           45                 10                5
# 2             20           40                 10                5
# 3             28           25                 10                2
# 4             20           40                  9                6
#
#    Vitamin_D (µg)  Magnesium (mg)  Selenium (µg)  Omega-3 (ALA, g)  \
# 0            0.00             100             10              0.80
# 1            1.00             130             20              0.30
# 2            9.00             120             30              0.20
# 3            2.00              90             20              0.30
# 4            1.00             120             20              0.40
#
#    EPA + DHA (mg)
# 0               0
# 1               0
# 2             300
# 3              50
# 4             100

# %%
# =========================================================
# Cell 2: Standardize column names and day ordering
# =========================================================
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "")
    .str.replace(")", "")
    .str.replace("+", "plus")
    .str.replace("µ", "u")
    .str.replace("-", "_")
)

weekday_order = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
df["meal_day"] = df["meal_day"].str.strip().str.lower()
df["meal_day"] = pd.Categorical(df["meal_day"], categories=weekday_order, ordered=True)

print("✅ Columns standardized and weekdays ordered.")
df.head(3)
# Out:
# ✅ Columns standardized and weekdays ordered.
#   meal_plan meal_day  meal_time                   meal_name  \
# 0    Plan A   monday    Morning           Oatmeal & Berries
# 1    Plan A   monday  Afternoon  Chicken & Black Bean Salad
# 2    Plan A   monday    Evening     Grilled Salmon & Quinoa
#
#                                     meal_description  calories_kcal  \
# 0  Steel-cut oats with almonds, flaxseed, and mix...            450
# 1  Grilled chicken and black bean salad with spin...            700
# 2  Grilled salmon with lemon-dill, quinoa, and ro...            850
#
#    total_fat_g  protein_g  dietary_fiber_g  added_sugar_g  vitamin_d_ug  \
# 0           15         15               10              5          0.00
# 1           25         45               10              5          1.00
# 2           20         40               10              5          9.00
#
#    magnesium_mg  selenium_ug  omega_3_ala,_g  epa_plus_dha_mg
# 0           100           10            0.80                0
# 1           130           20            0.30                0
# 2           120           30            0.20              300

# %%
# =========================================================
# Cell 3: Define nutrient target ranges (from WHO / NIH / DRI)
# =========================================================
nutrient_ranges = {
    "calories_kcal": (1900, 2100),
    "total_fat_g": (44, 78),
    "protein_g": (50, 175),
    "dietary_fiber_g": (26, 30),
    "added_sugar_g": (0, 50),
    "omega_3_alag": (1.1, 1.6),
    "epa_plus_dha_mg": (250, 500),
    "selenium_ug": (52, 58),
    "magnesium_mg": (310, 420),
    "vitamin_d_ug": (5, 15)
}

ranges_df = pd.DataFrame([
    {"Nutrient": k, "Min_Recommended": v[0], "Max_Recommended": v[1]}
    for k, v in nutrient_ranges.items()
])

print("✅ Real-world nutrient ranges used for compliance:")
display(ranges_df)
# Out:
# ✅ Real-world nutrient ranges used for compliance:
#           Nutrient  Min_Recommended  Max_Recommended
# 0    calories_kcal          1900.00          2100.00
# 1      total_fat_g            44.00            78.00
# 2        protein_g            50.00           175.00
# 3  dietary_fiber_g            26.00            30.00
# 4    added_sugar_g             0.00            50.00
# 5     omega_3_alag             1.10             1.60
# 6  epa_plus_dha_mg           250.00           500.00
# 7      selenium_ug            52.00            58.00
# 8     magnesium_mg           310.00           420.00
# 9     vitamin_d_ug             5.00            15.00

# %%
# =========================================================
# Cell 4: Map dataset columns to nutrient keys dynamically
# =========================================================
col_map = {}
for key in nutrient_ranges.keys():
    best = get_close_matches(key, df.columns, n=1, cutoff=0.5)
    if best:
        col_map[key] = best[0]

print("✅ Column mapping established:")
for k, v in col_map.items():
    print(f"  {k:20} --> {v}")

# Convert to numeric
for col in col_map.values():
    df[col] = pd.to_numeric(df[col], errors="coerce")

df.head(3)
# Out:
# ✅ Column mapping established:
#   calories_kcal        --> calories_kcal
#   total_fat_g          --> total_fat_g
#   protein_g            --> protein_g
#   dietary_fiber_g      --> dietary_fiber_g
#   added_sugar_g        --> added_sugar_g
#   omega_3_alag         --> omega_3_ala,_g
#   epa_plus_dha_mg      --> epa_plus_dha_mg
#   selenium_ug          --> selenium_ug
#   magnesium_mg         --> magnesium_mg
#   vitamin_d_ug         --> vitamin_d_ug
#   meal_plan meal_day  meal_time                   meal_name  \
# 0    Plan A   monday    Morning           Oatmeal & Berries
# 1    Plan A   monday  Afternoon  Chicken & Black Bean Salad
# 2    Plan A   monday    Evening     Grilled Salmon & Quinoa
#
#                                     meal_description  calories_kcal  \
# 0  Steel-cut oats with almonds, flaxseed, and mix...            450
# 1  Grilled chicken and black bean salad with spin...            700
# 2  Grilled salmon with lemon-dill, quinoa, and ro...            850
#
#    total_fat_g  protein_g  dietary_fiber_g  added_sugar_g  vitamin_d_ug  \
# 0           15         15               10              5          0.00
# 1           25         45               10              5          1.00
# 2           20         40               10              5          9.00
#
#    magnesium_mg  selenium_ug  omega_3_ala,_g  epa_plus_dha_mg
# 0           100           10            0.80                0
# 1           130           20            0.30                0
# 2           120           30            0.20              300

# %%
# =========================================================
# Cell 5: Aggregate nutrients by meal_plan and meal_day
# =========================================================
agg_cols = list(col_map.values())
daily = df.groupby(["meal_plan", "meal_day"], as_index=False)[agg_cols].sum()

print("✅ Aggregated nutrient totals per plan/day:")
display(daily.head())
# Out:
# ✅ Aggregated nutrient totals per plan/day:
# /var/folders/jg/8wn2439s6y312d5jyqw78pc80000gn/T/ipykernel_40261/410487024.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   daily = df.groupby(["meal_plan", "meal_day"], as_index=False)[agg_cols].sum()
#   meal_plan   meal_day  calories_kcal  total_fat_g  protein_g  \
# 0    Plan A     monday           2000           60        100
# 1    Plan A    tuesday           2000           68        110
# 2    Plan A  wednesday           1950           75        100
# 3    Plan A   thursday           1950           65        100
# 4    Plan A     friday           1900           60        115
#
#    dietary_fiber_g  added_sugar_g  omega_3_ala,_g  epa_plus_dha_mg  \
# 0               30             15            1.30              300
# 1               29             12            1.30              300
# 2               30             18            1.40                0
# 3               31             11            1.30              260
# 4               30             17            1.30              300
#
#    selenium_ug  magnesium_mg  vitamin_d_ug
# 0           60           350         10.00
# 1           60           320          5.00
# 2           55           340          7.00
# 3           65           350         10.00
# 4           55           330          6.00

# %%
# =========================================================
# Cell 6: Compare generated values vs real-world target ranges
# =========================================================
plan_example = daily[daily["meal_plan"].str.contains("", case=False)].head(3)
compare_table = []

for nutrient, (low, high) in nutrient_ranges.items():
    col = col_map[nutrient]
    for _, r in plan_example.iterrows():
        compare_table.append({
            "Meal_Plan": r["meal_plan"],
            "Meal_Day": r["meal_day"],
            "Nutrient": nutrient,
            "Generated_Value": round(r[col], 2),
            "Target_Range": f"{low} - {high}"
        })

compare_df = pd.DataFrame(compare_table)
display(compare_df)
# Out:
#    Meal_Plan   Meal_Day         Nutrient  Generated_Value Target_Range
# 0     Plan A     monday    calories_kcal          2000.00  1900 - 2100
# 1     Plan A    tuesday    calories_kcal          2000.00  1900 - 2100
# 2     Plan A  wednesday    calories_kcal          1950.00  1900 - 2100
# 3     Plan A     monday      total_fat_g            60.00      44 - 78
# 4     Plan A    tuesday      total_fat_g            68.00      44 - 78
# 5     Plan A  wednesday      total_fat_g            75.00      44 - 78
# 6     Plan A     monday        protein_g           100.00     50 - 175
# 7     Plan A    tuesday        protein_g           110.00     50 - 175
# 8     Plan A  wednesday        protein_g           100.00     50 - 175
# 9     Plan A     monday  dietary_fiber_g            30.00      26 - 30
# 10    Plan A    tuesday  dietary_fiber_g            29.00      26 - 30
# 11    Plan A  wednesday  dietary_fiber_g            30.00      26 - 30
# 12    Plan A     monday    added_sugar_g            15.00       0 - 50
# 13    Plan A    tuesday    added_sugar_g            12.00       0 - 50
# 14    Plan A  wednesday    added_sugar_g            18.00       0 - 50
# 15    Plan A     monday     omega_3_alag             1.30    1.1 - 1.6
# 16    Plan A    tuesday     omega_3_alag             1.30    1.1 - 1.6
# 17    Plan A  wednesday     omega_3_alag             1.40    1.1 - 1.6
# 18    Plan A     monday  epa_plus_dha_mg           300.00    250 - 500
# 19    Plan A    tuesday  epa_plus_dha_mg           300.00    250 - 500
# 20    Plan A  wednesday  epa_plus_dha_mg             0.00    250 - 500
# 21    Plan A     monday      selenium_ug            60.00      52 - 58
# 22    Plan A    tuesday      selenium_ug            60.00      52 - 58
# 23    Plan A  wednesday      selenium_ug            55.00      52 - 58
# 24    Plan A     monday     magnesium_mg           350.00    310 - 420
# 25    Plan A    tuesday     magnesium_mg           320.00    310 - 420
# 26    Plan A  wednesday     magnesium_mg           340.00    310 - 420
# 27    Plan A     monday     vitamin_d_ug            10.00       5 - 15
# 28    Plan A    tuesday     vitamin_d_ug             5.00       5 - 15
# 29    Plan A  wednesday     vitamin_d_ug             7.00       5 - 15
